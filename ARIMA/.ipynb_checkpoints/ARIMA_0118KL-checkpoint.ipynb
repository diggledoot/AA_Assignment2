# %% [markdown]
# # ARIMA for 0118.KL

# %% [markdown]
# ## Data Preparation

# %%
#general
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import yfinance as yf
from pmdarima.arima import ADFTest
from pandas_datareader import data as pdr

# %%
def check(x):
    adf = ADFTest()
    print("ADF:",adf.is_stationary(x)[1])

# %%
yf.pdr_override()
#load ticker for stock
df = pdr.get_data_yahoo("0118.KL", period="max", end="2020-04-30")
df.columns = [str(x).lower().replace(' ', '_') for x in df.columns]
# Change all column headings to be lower case, and remove spacing
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#              open   high    low  close  adj_close   volume
# Date
# 2020-03-06  0.005  0.010  0.005  0.005      0.005  6251800
# 2020-03-09  0.005  0.010  0.005  0.010      0.010  3149200
# 2020-03-10  0.010  0.010  0.005  0.010      0.010   168000
# 2020-03-11  0.005  0.005  0.005  0.005      0.005   333000
# 2020-03-12  0.010  0.010  0.005  0.010      0.010  1115000

# %%
df = df.filter(items=['adj_close'])
check(df)
# Out:
# ADF: True
# C:\Users\Teradon\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: is_stationary is deprecated and will be removed in a future release of pmdarima. Use should_diff instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
n=366
train = df[:-n]
test = df[-n:]
plt.figure(figsize=(12,8))
plt.plot(train)
plt.plot(test)
plt.show()

# %% [markdown]
# ## Training the model

# %%
from pmdarima import auto_arima

model = auto_arima(train,trace=True,m=7,error_action='ignore', suppress_warnings=True)
model.fit(train)
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(2,1,2)x(1,0,1,7) [intercept=True]; AIC=-20641.337, BIC=-20593.073, Time=3.277 seconds
# Fit ARIMA(0,1,0)x(0,0,0,7) [intercept=True]; AIC=-20614.329, BIC=-20602.263, Time=0.284 seconds
# Fit ARIMA(1,1,0)x(1,0,0,7) [intercept=True]; AIC=-20645.488, BIC=-20621.356, Time=1.037 seconds
# Fit ARIMA(0,1,1)x(0,0,1,7) [intercept=True]; AIC=-20646.496, BIC=-20622.364, Time=1.732 seconds
# Fit ARIMA(0,1,0)x(0,0,0,7) [intercept=False]; AIC=-20616.311, BIC=-20610.278, Time=0.267 seconds
# Fit ARIMA(0,1,1)x(0,0,0,7) [intercept=True]; AIC=-20624.008, BIC=-20605.909, Time=0.415 seconds
# Fit ARIMA(0,1,1)x(1,0,1,7) [intercept=True]; AIC=-20644.926, BIC=-20614.761, Time=2.314 seconds
# Fit ARIMA(0,1,1)x(0,0,2,7) [intercept=True]; AIC=-20645.758, BIC=-20615.593, Time=2.956 seconds
# Fit ARIMA(0,1,1)x(1,0,0,7) [intercept=True]; AIC=-20645.109, BIC=-20620.977, Time=1.624 seconds
# Fit ARIMA(0,1,1)x(1,0,2,7) [intercept=True]; AIC=-20643.754, BIC=-20607.556, Time=9.786 seconds
# Fit ARIMA(0,1,0)x(0,0,1,7) [intercept=True]; AIC=-20638.420, BIC=-20620.321, Time=2.037 seconds
# Fit ARIMA(1,1,1)x(0,0,1,7) [intercept=True]; AIC=-20645.158, BIC=-20614.993, Time=1.414 seconds
# Fit ARIMA(0,1,2)x(0,0,1,7) [intercept=True]; AIC=-20645.746, BIC=-20615.581, Time=1.662 seconds
# Fit ARIMA(1,1,0)x(0,0,1,7) [intercept=True]; AIC=-20646.874, BIC=-20622.742, Time=1.467 seconds
# Fit ARIMA(1,1,0)x(0,0,0,7) [intercept=True]; AIC=-20624.399, BIC=-20606.300, Time=0.419 seconds
# Fit ARIMA(1,1,0)x(1,0,1,7) [intercept=True]; AIC=-20645.305, BIC=-20615.140, Time=1.831 seconds
# Fit ARIMA(1,1,0)x(0,0,2,7) [intercept=True]; AIC=-20646.138, BIC=-20615.973, Time=3.144 seconds
# Fit ARIMA(1,1,0)x(1,0,2,7) [intercept=True]; AIC=-20644.134, BIC=-20607.936, Time=4.532 seconds
# Fit ARIMA(2,1,0)x(0,0,1,7) [intercept=True]; AIC=-20645.411, BIC=-20615.246, Time=1.795 seconds
# Fit ARIMA(2,1,1)x(0,0,1,7) [intercept=True]; AIC=-20643.543, BIC=-20607.345, Time=4.537 seconds
# Total fit time: 46.593 seconds
# ARIMA(order=(1, 1, 0), seasonal_order=(0, 0, 1, 7), suppress_warnings=True)

# %% [markdown]
# ## Forecasting on the dataset

# %%
forecast = model.predict(n_periods=n)
forecast = pd.DataFrame(forecast,index = test.index,columns=['Prediction'])

# %%
plt.plot(train, label='Train')
plt.plot(test, label='Valid')
plt.plot(forecast, label='Prediction')
plt.show()

# %% [markdown]
# ## Evaluating the training model

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(test,forecast['Prediction']))
# Out:
# 7.901990162861282e-06

# %% [markdown]
# ## Forecasting beyond the dataset

# %%
model.update(test)
# Out:
# ARIMA(order=(1, 1, 0), seasonal_order=(0, 0, 1, 7), suppress_warnings=True)

# %%
dates = pd.date_range(start='2020-05-01', periods=n)

# %%
forecast = model.predict(n_periods=n)
forecast = pd.DataFrame(forecast,index = dates,columns=['Prediction'])

# %%
forecast.tail()
# Out:
#             Prediction
# 2021-04-27    0.000852
# 2021-04-28    0.000825
# 2021-04-29    0.000799
# 2021-04-30    0.000773
# 2021-05-01    0.000746

# %%
plt.figure(figsize=(12,8))
plt.plot(train,label="Train")
plt.plot(test,label='Test')
plt.plot(forecast,label='Forecast')
plt.show()
